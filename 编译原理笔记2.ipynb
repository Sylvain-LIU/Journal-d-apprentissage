# %% [markdown]
# # 编译原理笔记2

# %%
简单的一遍编译器：
词法分析
语法分析
中间代码生成

程序设计语言可以通过描述语法和语义两个方面来定义。

语法制导翻译技术。比如把中缀表达式转换成后缀表达式。

词法词法分析器：把输入字符流转换成记号流。
编译器前端的结构：字符流——词法分析器——记号流——语法知道翻译器——中间表示

语法定义。上下文无关文法。
1、一个记号集合，称为终结符号。
2、一个非终结符集合。
3、一个产生式集合
4、一个开始符号。

分析树。
1、树根标记为开始符号。
2、每个叶节点由记号或者ɛ标记。
3、每个内节点有一个非终结符标记。
一颗分析树从左到右的叶节点是这颗分析树生成的结果。为给定的记号窜找到一个分析树的过程称为这个窜的语法分析。

二义性。
一颗分析树读完它的叶节点只能生成唯一的一个串。但是，一个文法可能有多个分析树生成相同的记号串。这样的文法称为具有二义性的文法。
